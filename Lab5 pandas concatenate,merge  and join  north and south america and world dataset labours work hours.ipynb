# %% [markdown]
# Nivashini J
#
#
#
#
#
# I M.Sc DATA SCIENCE

# %%
import pandas as pd

# %%
north_america=pd.read_csv("north_america_2000_2010.csv",index_col=0)

# %%
south_america=pd.read_csv("south_america_2000_2010.csv",index_col=0)

# %%
north_america
# Out:
#            2000    2001    2002    2003    2004  2005    2006    2007  2008  \
# Country
# Canada   1779.0  1771.0  1754.0  1740.0  1760.0  1747  1745.0  1741.0  1735
# Mexico   2311.2  2285.2  2271.2  2276.5  2270.6  2281  2280.6  2261.4  2258
# USA      1836.0  1814.0  1810.0  1800.0  1802.0  1799  1800.0  1798.0  1792
#
#            2009    2010
# Country
# Canada   1701.0  1703.0
# Mexico   2250.2  2242.4
# USA      1767.0  1778.0

# %%
south_america
# Out:
#          2000  2001  2002  2003  2004  2005  2006  2007  2008  2009    2010
# Country
# Chile    2263  2242  2250  2235  2232  2157  2165  2128  2095  2074  2069.6

# %%
north_america.plot()
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
north_america.transpose().plot(title="Avarage Labor Hours Per Year")
# Out:
# <AxesSubplot:title={'center':'Avarage Labor Hours Per Year'}>

# %%
north_america.transpose().plot(title="Avarage Labor Hours Per Year")
# Out:
# <AxesSubplot:title={'center':'Avarage Labor Hours Per Year'}>

# %% [markdown]
# ### Concatenate America Data
#
# It’s hard to compare the average labor hours in South America versus North America. If we were able to get all
# the countries into the same data frame, it would be much easier to do this camparison.

# %% [markdown]
# #### Concatenate north_america and south_america dataframes and store result in a dataframe,americas

# %%
Americas=pd.concat([north_america,south_america])
Americas
# Out:
#            2000    2001    2002    2003    2004  2005    2006    2007  2008  \
# Country
# Canada   1779.0  1771.0  1754.0  1740.0  1760.0  1747  1745.0  1741.0  1735
# Mexico   2311.2  2285.2  2271.2  2276.5  2270.6  2281  2280.6  2261.4  2258
# USA      1836.0  1814.0  1810.0  1800.0  1802.0  1799  1800.0  1798.0  1792
# Chile    2263.0  2242.0  2250.0  2235.0  2232.0  2157  2165.0  2128.0  2095
#
#            2009    2010
# Country
# Canada   1701.0  1703.0
# Mexico   2250.2  2242.4
# USA      1767.0  1778.0
# Chile    2074.0  2069.6

# %% [markdown]
# Now, our data collection team has sent us data files for each year from 2011 to 2015 in separate CSV files. They
# are americas_2011.csv , americas_2012.csv, americas_2014.csv and americas_2015.csv

# %% [markdown]
# #### Load the additional files

# %%
americas_dfs=[Americas]

for year in range(2011,2016):
    file_name="americas_{}.csv".format(year)
    df=pd.read_csv(file_name,index_col=0)
    americas_dfs.append(df)

# %%
americas_dfs[1]
# Out:
#            2011
# Country
# Canada   1700.0
# Chile    2047.4
# Mexico   2250.2
# USA      1786.0

# %%
americas_dfs[2]
# Out:
# Germany         1424.4  1418.4  1372.7  1389.9  1392.8  1375.3  1361.7
#
#                   2014    2015
# Country
# Austria         1629.4  1624.9
# Belgium         1560.0  1541.0
# Switzerland     1568.3  1589.7
# Czech Republic  1771.0  1779.0
# Germany         1366.4  1371.0

# %%
south_pacific=pd.read_csv("south_pacific_2000_2015.csv",index_col=0)
south_pacific.head()
# Out:
#                2000    2001    2002    2003    2004    2005    2006    2007  \
# Country
# Australia    1778.7  1736.7  1731.7  1735.8  1734.5  1729.2  1720.5  1712.5
# New Zealand  1836.0  1825.0  1826.0  1823.0  1830.0  1815.0  1795.0  1774.0
#
#                2008  2009    2010    2011    2012    2013    2014  2015
# Country
# Australia    1717.2  1690  1691.5  1699.5  1678.6  1662.7  1663.6  1665
# New Zealand  1761.0  1740  1755.0  1746.0  1734.0  1752.0  1762.0  1757

# %%
world=americas.append([asia,europe,south_pacific])
# Out:
# C:\Users\1mscds08\AppData\Local\Temp\ipykernel_15184\2482502302.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   world=americas.append([asia,europe,south_pacific])

# %%
world.index
# Out:
# Index(['Canada', 'Mexico', 'USA', 'Chile', 'Israel', 'Japan', 'Korea',
#        'Russia', 'Austria', 'Belgium', 'Switzerland', 'Czech Republic',
#        'Germany', 'Denmark', 'Spain', 'Estonia', 'Finland', 'France',
#        'United Kingdom', 'Greece', 'Hungary', 'Ireland', 'Iceland', 'Italy',
#        'Lithuania', 'Luxembourg', 'Latvia', 'Netherlands', 'Norway', 'Poland',
#        'Portugal', 'Slovak Republic', 'Slovenia', 'Sweden', 'Australia',
#        'New Zealand'],
#       dtype='object')

# %%
world.transpose().plot()
# Out:
# <AxesSubplot:>

# %%
world.transpose().plot(figsize=(8,10),colormap="rainbow",linewidth=2).legend(loc="right")

# %%
historical=pd.read_csv("historical.csv")
historical.head()
# Out:
#        Country  1950  1951  1952  1953  1954  1955  1956  1957  1958  ...  \
# 0    Australia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1      Austria   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2      Belgium   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3       Canada   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  Switzerland   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#      1990     1991     1992     1993     1994      1995      1996      1997  \
# 0  1779.5  1774.90  1773.70  1786.50  1797.60  1793.400  1782.700  1783.600
# 1     NaN      NaN      NaN      NaN      NaN  1619.200  1637.150  1648.500
# 2  1662.9  1625.79  1602.72  1558.59  1558.59  1515.835  1500.295  1510.315
# 3  1789.5  1767.50  1766.00  1764.50  1773.00  1771.500  1786.500  1782.500
# 4     NaN  1673.10  1684.80  1685.80  1706.20  1685.500  1658.900  1648.600
#
#       1998    1999
# 0  1768.40  1778.8
# 1  1641.65  1654.0
# 2  1513.33  1514.5
# 3  1778.50  1778.5
# 4  1656.60  1678.4
#
# [5 rows x 51 columns]

# %%
print(world.shape,"world rows & columns")
print(historical.shape,"Historical rows & columns")
# Out:
# (36, 16) world rows & columns
# (39, 51) Historical rows & columns

# %%
world_historical=pd.merge(world,historical,left_index=True,right_index=True,)
world_historical
# Out:
# Empty DataFrame
# Columns: [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, Country, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999]
# Index: []
#
# [0 rows x 67 columns]

# %%
world_historical.shape
# Out:
# (0, 67)

# %%
world_historical.head()
# Out:
# Empty DataFrame
# Columns: [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, Country, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999]
# Index: []
#
# [0 rows x 67 columns]

# %%
world_historical=historical.join(world,how='right')

# %%
world_historical.head()
# Out:
#        Country  1950  1951  1952  1953  1954  1955  1956  1957  1958  ...  \
# Canada     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Mexico     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# USA        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Chile      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Israel     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#           2006    2007    2008    2009    2010    2011    2012    2013  \
# Canada  1745.0  1741.0  1735.0  1701.0  1703.0  1700.0  1713.0  1707.0
# Mexico  2280.6  2261.4  2258.0  2250.2  2242.4  2250.2  2225.8  2236.6
# USA     1800.0  1798.0  1792.0  1767.0  1778.0  1786.0  1789.0  1787.0
# Chile   2165.0  2128.0  2095.0  2074.0  2069.6  2047.4  2024.0  2015.3
# Israel  1919.0  1931.0  1929.0  1927.0  1918.0  1920.0  1910.0  1867.0
#
#           2014    2015
# Canada  1703.0  1706.0
# Mexico  2228.4  2246.4
# USA     1789.0  1790.0
# Chile   1990.1  1987.5
# Israel  1853.0  1858.0
#
# [5 rows x 67 columns]

# %%
world_historical.transpose().plot(figsize=(12,8),colormap="rainbow",linewidth=2).legend(loc="right")

# %%
world_historical.index.max()
# Out:
# 'United Kingdom'

# %%
world_historical.index.min()
# Out:
# 'Australia'
