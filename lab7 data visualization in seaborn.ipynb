# %% [markdown]
# Nivashini J
#
#
#
#
# I M.Sc DATA SCIENCE

# %% [markdown]
#                                                    DATA VISUALIZATION IN SEABORN

# %% [markdown]
# 1) VISUALIZING STATISTICAL RELATIONSHIPS
#
#
#
#
# scatter plot, relplot, hueplot, lineplot

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import pandas as pd 
from scipy import stats

# %%
df = pd.read_csv(r"train_upvote_mini.csv") 
df.head()
# Out:
#        ID Tag  Reputation  Answers  Username    Views  Upvotes
# 0   52664   a      3942.0      2.0    155623   7855.0     42.0
# 1  327662   a     26046.0     12.0     21781  55801.0   1175.0
# 2  468453   c      1358.0      4.0     56177   8067.0     60.0
# 3   96996   a       264.0      3.0    168793  27064.0      9.0
# 4  131465   c      4271.0      4.0    112223  13986.0     83.0

# %%
df.shape
# Out:
# (15440, 7)

# %%
df.dtypes
# Out:
# ID              int64
# Tag            object
# Reputation    float64
# Answers       float64
# Username        int64
# Views         float64
# Upvotes       float64
# dtype: object

# %%
df['Tag'].unique()
# Out:
# array(['a', 'c', 'r', 'j', 'p', 's', 'h', 'o', 'i', 'x'], dtype=object)

# %%
plt.scatter(x=df['Views'], y=df['Upvotes'])

# %%
sns.relplot(data=df, x="Views", y="Upvotes")

# %%
sns.relplot(data=df, x="Views", y="Upvotes", hue='Tag')

# %%
sns.relplot(data=df, x="Views", y="Upvotes", hue='Answers')

# %%
sns.relplot(data=df, x="Views", y="Upvotes", size = 'Tag')

# %%
sns.relplot(data=df, x="Answers", y="Upvotes", kind='line')

# %%
sns.relplot(data=df, x="Reputation", y="Upvotes")

# %% [markdown]
# 2)VISUALIZING CATEGORICAL DATA
#
#
#      CATEGORICAL SCATTERPLOTS  - stripplot, swarmplot
#
#      CATEGORICAL DISTRIBUTION PLOTS-boxplot, violinplot,boxenplot
#
#      CATEGORICAL ESTIMATE PLOTS-pointplot, barplot, countplot

# %%
df2 = pd.read_csv('train_hr_mini.csv')

# %%
df2
# Out:
#       employee_id         department     region         education gender  \
# 0           65438  Sales & Marketing   region_7  Master's & above      f
# 1           65141         Operations  region_22        Bachelor's      m
# 2            7513  Sales & Marketing  region_19        Bachelor's      m
# 3            2542  Sales & Marketing  region_23        Bachelor's      m
# 4           48945         Technology  region_26        Bachelor's      m
# ...           ...                ...        ...               ...    ...
# 6392        37940            Finance  region_20        Bachelor's      m
# 6393        25428  Sales & Marketing   region_2        Bachelor's      f
# 6394        26432  Sales & Marketing  region_22        Bachelor's      m
# 6395          912  Sales & Marketing  region_31        Bachelor's      f
# 6396         2387  Sales & Marketing   region_4        Bachelor's      m
#
#      recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0               sourcing                1   35                   5.0
# 1                  other                1   30                   5.0
# 2               sourcing                1   34                   3.0
# 3                  other                2   39                   1.0
# 4                  other                1   45                   3.0
# ...                  ...              ...  ...                   ...
# 6392            sourcing                1   35                   4.0
# 6393            sourcing                1   29                   4.0
# 6394            sourcing                4   30                   NaN
# 6395               other                2   25                   3.0
# 6396               other                1   27                   NaN
#
#       length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                     8              1            0                  49
# 1                     4              0            0                  60
# 2                     7              0            0                  50
# 3                    10              0            0                  50
# 4                     2              0            0                  73
# ...                 ...            ...          ...                 ...
# 6392                  7              0            0                  57
# 6393                  5              0            0                  48
# 6394                  1              0            0                  49
# 6395                  2              0            0                  53
# 6396                  1              0            0                  51
#
#       is_promoted
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 6392            0
# 6393            0
# 6394            0
# 6395            0
# 6396            0
#
# [6397 rows x 14 columns]

# %%
df2.shape
# Out:
# (6397, 14)

# %%
sns.stripplot(data=df2, x="education", y="avg_training_score", jitter=True)
# Out:
# <Axes: xlabel='education', ylabel='avg_training_score'>

# %%
sns.stripplot(data=df2, x="education", y="avg_training_score", jitter=False)
# Out:
# <Axes: xlabel='education', ylabel='avg_training_score'>

# %%
sns.swarmplot(data=df2, x="education", y="avg_training_score")
# Out:
# C:\Users\nivet\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 71.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\nivet\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 88.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='education', ylabel='avg_training_score'>
# C:\Users\nivet\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 76.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\nivet\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 89.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\nivet\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data=df2, x="education", y="avg_training_score", hue = 'gender')
# Out:
# C:\Users\nivet\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 71.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\nivet\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 88.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='education', ylabel='avg_training_score'>
# C:\Users\nivet\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 76.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\nivet\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 89.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\nivet\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data=df2, x="education", y="avg_training_score", hue='is_promoted)
# Out:
#   Cell In[22], line 1
#     sns.swarmplot(data=df2, x="education", y="avg_training_score", hue='is_promote
#                                                                        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
sns.boxplot(data=df2, x="education", y="avg_training_score")

# %%
sns.boxplot(data=df2, x="education", y="avg_training_score", hue = 'is_promoted)

# %%
sns. violinplot(data=df2, x="education", y="avg_training_score", hue='is_promoted)

# %%
sns.barplot(data=df2, x="education", y="avg_training_score", hue='is_promoted)

# %%
sns.pointplot(data=df2, x="education", y="avg_training_score", hue = "is_promoted")

# %%
#draw swaem

# %%
sns.catplot(x="education", y="avg_training_score", hue="is_promoted", col="gender",aspect=9,kind="swarm",data=df2)

# %% [markdown]
# Visualizing the distribution of data

# %% [markdown]
# plot Univariate Distribution
#
#
# plot hist with kernel density estimate value for age attrtibute
#  and without kernal (kde)

# %%
sns.histplot(x='age', data=df1, kde=True)

# %%
sns.histplot(x='age', data=df1)

# %%
#Plot Bivariate distribution
#join plot and with hex plot

# %%
sns.jointplot(x=' avg_training_score',y='age', data=df1 )

# %%
sns.jointplot(x=' avg_training_score',y='age', kind='hex', data=df1 )

# %%
#kde plot

# %%
sns.kdeplot(x='age',y='avg_training_score', data=df1 )

# %%
#heat map

# %%
sns.heatmap(df2.corr())
# Out:
# C:\Users\nivet\AppData\Local\Temp\ipykernel_13692\3362918621.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df2.corr())
# <Axes: >

# %%
#boxen plot

# %%
 sns.catplot(x='age',y='avg_training_score', data=df2, kind='boxen')

# %%
pair plot

# %%
sns.pairplot(df2)
